# %%
# !source AI4INDUSTRY-env/bin/activate

# %%
# !pip install odfpy
# !pip install pandas
# !pip install openpyxl
# !pip install requests

# %%
import pandas as pd

# %%
df = pd.read_excel('uc-data/Etude client 1 finale.xlsx').drop_duplicates().drop(['Horodateur', 'Unnamed: 1', 'Unnamed: 2'], axis=1)
df
# Out:
#     Boutique code postal  \
# 0      Socoa       64310
# 1      Socoa       80209
# 2      Socoa       40920
# 3      Socoa       40920
# 4      Socoa       94000
# ..       ...         ...
# 240  St Jean       64310
# 241  St Jean       64500
# 242  St Jean       64500
# 243  St Jean       64122
# 244  St Jean       64500
#
#     Depuis combien de temps êtes vous un client de la Maison Pariès ?  \
# 0                               Depuis quelques années
# 1                   C’est une de mes premières visites
# 2                               Depuis quelques années
# 3                               Depuis quelques années
# 4                   C’est une de mes premières visites
# ..                                                 ...
# 240                             Depuis quelques années
# 241                                    Depuis toujours
# 242                             Depuis quelques années
# 243                                    Depuis toujours
# 244                 C’est une de mes premières visites
#
#     A quelle fréquence venez-vous nous rendre visite ?  \
# 0                                     visite mensuelle
# 1                             C'est la première fois !
# 2                                     visite mensuelle
# 3                                  visite hebdomadaire
# 4                             C'est la première fois !
# ..                                                 ...
# 240                                   visite mensuelle
# 241                                visite hebdomadaire
# 242                                   visite mensuelle
# 243                              visite exceptionnelle
# 244                           C'est la première fois !
#
#      Comment nous avez-vous connus ?  \
# 0                   bouche à oreille
# 1       par hasard en passant devant
# 2    avec vos parents; votre famille
# 3    avec vos parents; votre famille
# 4       par hasard en passant devant
# ..                               ...
# 240     par hasard en passant devant
# 241     par hasard en passant devant
# 242  avec vos parents, votre famille
# 243  avec vos parents, votre famille
# 244     par hasard en passant devant
#
#     En 2 mots, comment définiriez-vous la Maison ?  \
# 0                                 Mouchous; glaces
# 1                         Artisanat; gastronomique
# 2                                         Tres bon
# 3                                         Tres bon
# 4                              Orange; accueillant
# ..                                             ...
# 240                             Qualite; tradition
# 241                                   Tout va bien
# 242                           Qualite,;gourmandise
# 243                                        Qualite
# 244                                 Belle boutique
#
#     A quelle(s) occasion(s) effectuez-vous des achats chez nous  \
# 0    pour me faire plaisir; quand je reçois du mond...
# 1                                pour me faire plaisir
# 2                                pour me faire plaisir
# 3                                pour me faire plaisir
# 4                                pour me faire plaisir
# ..                                                 ...
# 240        pour me faire plaisir; pour faire un cadeau
# 241  pour me faire plaisir; quand je reçois du mond...
# 242        pour me faire plaisir; pour faire un cadeau
# 243  pour me faire plaisir; pour faire un cadeau; q...
# 244                              pour me faire plaisir
#
#     Quel est le produit que vous préférez ?  \
# 0                       Gateau basque creme
# 1                                       NaN
# 2               Gateau basque a la noisette
# 3                Gateau basque au noisettes
# 4                             Gateau basque
# ..                                      ...
# 240                  gateau basque chocolat
# 241                        Kanoougas; tarte
# 242                               Chocolats
# 243                               Chocolats
# 244                                     NaN
#
#     Quel est le dernier produit de la gamme Pariès que vous connaissez ?  \
# 0                               Les petites s noisette
# 1                                                  NaN
# 2                                 La buche au chocolat
# 3                        Les gateau de voyage chocolat
# 4                                                Aucun
# ..                                                 ...
# 240                                                NaN
# 241                                            Galette
# 242                                                NaN
# 243                                                NaN
# 244                                                NaN
#
#     8. Quels sont les produits de nos gammes que vous achetez chez d’autres artisans ?  \
# 0                                        Gateau basque
# 1                                        Gateau basque
# 2                                        Les chocolats
# 3                                        Les chocolats
# 4                                        Gateau basque
# ..                                                 ...
# 240                                          Chocolats
# 241                                          Chovolats
# 242                                      gateau basque
# 243                                      gateau basque
# 244                                                NaN
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 240  ...
# 241  ...
# 242  ...
# 243  ...
# 244  ...
#
#     Si vous n'êtes pas de la région, aimeriez-vous pouvoir trouver nos produits à proximité de votre domicile ?  \
# 0                                                  NaN
# 1                                                  oui
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  oui
# ..                                                 ...
# 240                                                NaN
# 241                                                NaN
# 242                                                NaN
# 243                                                NaN
# 244                                                NaN
#
#                Que devons-nous faire pour progresser ?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                        Des pieces montee en chocolat
# 3                  Faire des pieces monter en chocolat
# 4                      Degustation autre que chocolats
# ..                                                 ...
# 240  Apporter plus de patisseries chocolat; equipe ...
# 241                     Amabilite de certaine personne
# 242                                                NaN
# 243                                                NaN
# 244                                                NaN
#
#     14. Dans les grandes évolutions de la consommation, quelles sont les 3 qui vous tiennent le plus à cœur ?  \
# 0    Alimentation santé bien être et transparence; ...
# 1    Alimentation durable (naturalité, moins de gas...
# 2    Alimentation durable (naturalité, moins de gas...
# 3    Alimentation durable (naturalité, moins de gas...
# 4    Alimentation durable (naturalité, moins de gas...
# ..                                                 ...
# 240  Tradition et authenticité; Localisme (consomma...
# 241  Alimentation durable (naturalité, moins de gas...
# 242  Alimentation durable (naturalité, moins de gas...
# 243  Alimentation durable (naturalité, moins de gas...
# 244  Alimentation durable (naturalité, moins de gas...
#
#       Sexe Quelle est votre catégorie socio-professionnelle ? Tranche d'âge  \
# 0    Femme      Cadre et profession intellectuelle supérieure         35/49
# 1    Homme                                           Retraité       65 et +
# 2    Homme      Cadre et profession intellectuelle supérieure         25/34
# 3    Homme      Cadre et profession intellectuelle supérieure         25/34
# 4    Femme      Cadre et profession intellectuelle supérieure         35/49
# ..     ...                                                ...           ...
# 240  Homme             Artisan, commerçant, chef d'entreprise         50/64
# 241  Homme                                           Retraité       65 et +
# 242  Homme                                           Retraité       65 et +
# 243  Homme                                           Retraité         50/64
# 244  Femme                                Profession libérale         25/34
#
#     de combien de personnes se compose votre foyer ?  \
# 0                                                4.0
# 1                                                2.0
# 2                                                4.0
# 3                                                4.0
# 4                                                2.0
# ..                                               ...
# 240                                              5.0
# 241                                              2.0
# 242                                              2.0
# 243                                              2.0
# 244                                              3.0
#
#     S'il y a des enfants dans votre foyer, quel âge ont-ils ?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                           - de 5 ans
# 3                                           - de 5 ans
# 4                                                  NaN
# ..                                                 ...
# 240              entre 5 et 10 ans, entre 11 et 15 ans
# 241                                                NaN
# 242                                                NaN
# 243                                                NaN
# 244                                  entre 5 et 10 ans
#
#     Êtes-vous abonné à notre newsletter ?  \
# 0                                     Oui
# 1                                     Non
# 2                                     Non
# 3                                     Non
# 4                                     Non
# ..                                    ...
# 240                                   Non
# 241                                   Non
# 242                                   Non
# 243                                   Non
# 244                                   Non
#
#      Si non, confiez-moi votre adresse mail pour recevoir notre actualité (moins de 10 mails par an)
# 0                                           **********
# 1                                           **********
# 2                                           **********
# 3                                           **********
# 4                                                  NaN
# ..                                                 ...
# 240                                                NaN
# 241                                                NaN
# 242                                                NaN
# 243                                                NaN
# 244                                                NaN
#
# [245 rows x 23 columns]

# %%
# df2 = pd.read_excel('uc-data/etude client été finale.ods', engine='odf').drop_duplicates().drop(['Horodateur', 'Unnamed: 1', 'Unnamed: 2'], axis=1)
# df2 = df2.drop('Pourquoi ?.1', axis=1)
df2 = pd.read_csv('data_with_coordinates.csv')
df2.head(5)
# Out:
#   Boutique code postal  \
# 0  St Jean       31410
# 1  St Jean       64500
# 2  St Jean       62400
# 3  St Jean       33820
# 4  St Jean       64210
#
#   Depuis combien de temps êtes vous un client de la Maison Pariès ?  \
# 0                             Depuis quelques années
# 1                                    Depuis toujours
# 2                             Depuis quelques années
# 3                             Depuis quelques années
# 4                             Depuis quelques années
#
#   A quelle fréquence venez-vous nous rendre visite ?  \
# 0                              visite exceptionnelle
# 1                              visite exceptionnelle
# 2                                   visite mensuelle
# 3                              visite exceptionnelle
# 4                              visite exceptionnelle
#
#                   Comment nous avez-vous connus ?  \
# 0                                bouche à oreille
# 1                 avec vos parents, votre famille
# 2                    par hasard en passant devant
# 3                    par hasard en passant devant
# 4  par hasard en passant devant; bouche à oreille
#
#   En 2 mots, comment définiriez-vous la Maison ?  \
# 0                                    Accueillant
# 1                                    Bon; Fiable
# 2                                       Plaisant
# 3                                      Alléchant
# 4                             Savoureux; Raffiné
#
#   A quelle(s) occasion(s) effectuez-vous des achats chez nous  \
# 0     pour me faire plaisir; pour régaler ma famille
# 1  pour me faire plaisir; pour régaler ma famille...
# 2                              pour me faire plaisir
# 3        pour me faire plaisir; pour faire un cadeau
# 4        pour me faire plaisir; pour faire un cadeau
#
#   Quel est le produit que vous préférez ?  \
# 0                           Gateau basque
# 1                             Pâtisseries
# 2                  Gateau basque chocolat
# 3              Viennoiseries Royal Amande
# 4                         Mouchous amande
#
#   Quel est le dernier produit de la gamme Pariès que vous connaissez ?  \
# 0                                     Je ne sais pas
# 1                           Pâtisseries Béret basque
# 2                            Viennoiseries Tortillon
# 3                                      Gateau basque
# 4                          Gateau basque aux agrumes
#
#   8. Quels sont les produits de nos gammes que vous achetez chez d’autres artisans ?  \
# 0                                      Gateau basque
# 1                                              Aucun
# 2                                      Viennoiseries
# 3                                      Gateau basque
# 4                            Gateau basque; Chocolat
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   14. Dans les grandes évolutions de la consommation, quelles sont les 3 qui vous tiennent le plus à cœur ?  \
# 0  Alimentation durable (naturalité, moins de gas...
# 1       Alimentation santé bien être et transparence
# 2  Alimentation durable (naturalité, moins de gas...
# 3  Alimentation durable (naturalité, moins de gas...
# 4  Alimentation durable (naturalité, moins de gas...
#
#     Sexe Quelle est votre catégorie socio-professionnelle ? Tranche d'âge  \
# 0  Femme                                           Retraité       65 et +
# 1  Femme                                           Retraité       65 et +
# 2  Femme                                            Employé         25/34
# 3  Homme                                           Retraité         50/64
# 4  Femme                                            Employé         25/34
#
#   de combien de personnes se compose votre foyer ?  \
# 0                                              2.0
# 1                                              2.0
# 2                                              2.0
# 3                                              2.0
# 4                                              2.0
#
#   S'il y a des enfants dans votre foyer, quel âge ont-ils ?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Êtes-vous abonné à notre newsletter ?  \
# 0                                   Non
# 1                                   Non
# 2                                   Non
# 3                                   Non
# 4                                   Non
#
#   Si non, confiez-moi votre adresse mail pour recevoir notre actualité (moins de 10 mails par an)  \
# 0                                                NaN
# 1                                                NaN
# 2                                         **********
# 3                                                NaN
# 4                                                NaN
#
#          lat        lon
# 0  43.367108   1.272896
# 1  43.388867  -1.638179
# 2  50.528190   2.642115
# 3  61.466562  23.819322
# 4  43.437635  -1.585311
#
# [5 rows x 25 columns]

# %%
df2.isna().sum()
# Out:
# Boutique                                                                                                          0
# code postal                                                                                                       0
# Depuis combien de temps êtes vous un client de la Maison Pariès ?                                                 0
# A quelle fréquence venez-vous nous rendre visite ?                                                                0
# Comment nous avez-vous connus ?                                                                                   0
# En 2 mots, comment définiriez-vous la Maison ?                                                                    0
# A quelle(s) occasion(s) effectuez-vous des achats chez nous                                                       0
# Quel est le produit que vous préférez ?                                                                         156
# Quel est le dernier produit de la gamme Pariès que vous connaissez ?                                            212
# 8. Quels sont les produits de nos gammes que vous achetez chez d’autres artisans ?                              190
# Pourquoi ?                                                                                                      586
# Où achetez-vous nos produits ?                                                                                  168
# Avez-vous déjà eu l’occasion de commander nos produits sur notre site en ligne ?                                  0
# Si vous n'êtes pas de la région, aimeriez-vous pouvoir trouver nos produits à proximité de votre domicile ?     928
# Que devons-nous faire pour progresser ?                                                                         185
# 14. Dans les grandes évolutions de la consommation, quelles sont les 3 qui vous tiennent le plus à cœur ?        15
# Sexe                                                                                                              0
# Quelle est votre catégorie socio-professionnelle ?                                                                0
# Tranche d'âge                                                                                                     0
# de combien de personnes se compose votre foyer ?                                                                  4
# S'il y a des enfants dans votre foyer, quel âge ont-ils ?                                                       730
# Êtes-vous abonné à notre newsletter ?                                                                             0
# Si non, confiez-moi votre adresse mail pour recevoir notre actualité (moins de 10 mails par an)                1045
# lat                                                                                                               0
# lon                                                                                                               0
# dtype: int64

# %%
df2['code postal'] = df2['code postal'].astype(str).str.replace('*', '0')
# Out:
# /tmp/ipykernel_4141/1107489302.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df2['code postal'] = df2['code postal'].astype(str).str.replace('*', '0')

# %%
postal_list = list(set(df2['code postal'][df2['code postal'].astype(str).str.match(r'^\d{5}$')]))

# %%
postal_list = set(df2['code postal'].value_counts().keys().to_list())
postal_list[0:5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4141/1654043000.py in <module>
#       1 postal_list = set(df2['code postal'].value_counts().keys().to_list())
# ----> 2 postal_list[0:5]
#
# TypeError: 'set' object is not subscriptable

# %%
for i in zip(df[:].nunique().items(), df2[:].nunique().items()):
    print(i)
# Out:
# (('Boutique', 4), ('Boutique', 6))
# (('code postal', 117), ('code postal', 456))
# (('Depuis combien de temps êtes vous un client de la Maison Pariès ?', 4), ('Depuis combien de temps êtes vous un client de la Maison Pariès ?', 4))
# (('A quelle fréquence venez-vous nous rendre visite ?', 7), ('A quelle fréquence venez-vous nous rendre visite ?', 13))
# (('Comment nous avez-vous connus ?', 31), ('Comment nous avez-vous connus ?', 36))
# (('En 2 mots, comment définiriez-vous la Maison ?', 211), ('En 2 mots, comment définiriez-vous la Maison ?', 400))
# (('A quelle(s) occasion(s) effectuez-vous des achats chez nous', 26), ('A quelle(s) occasion(s) effectuez-vous des achats chez nous', 51))
# (('Quel est le produit que vous préférez ?', 118), ('Quel est le produit que vous préférez ?', 158))
# (('Quel est le dernier produit de la gamme Pariès que vous connaissez ?', 49), ('Quel est le dernier produit de la gamme Pariès que vous connaissez ?', 69))
# (('8. Quels sont les produits de nos gammes que vous achetez chez d’autres artisans ?', 54), ('8. Quels sont les produits de nos gammes que vous achetez chez d’autres artisans ?', 63))
# (('Pourquoi ?', 34), ('Pourquoi ?', 52))
# (('Où achetez-vous nos produits ?', 2), ('Où achetez-vous nos produits ?', 2))
# (('Avez-vous déjà eu l’occasion de commander nos produits sur notre site en ligne ?', 2), ('Avez-vous déjà eu l’occasion de commander nos produits sur notre site en ligne ?', 2))
# (("Si vous n'êtes pas de la région, aimeriez-vous pouvoir trouver nos produits à proximité de votre domicile ?", 2), ("Si vous n'êtes pas de la région, aimeriez-vous pouvoir trouver nos produits à proximité de votre domicile ?", 2))
# (('Que devons-nous faire pour progresser ?', 80), ('Que devons-nous faire pour progresser ?', 132))
# (('14. Dans les grandes évolutions de la consommation, quelles sont les 3 qui vous tiennent le plus à cœur ?', 37), ('14. Dans les grandes évolutions de la consommation, quelles sont les 3 qui vous tiennent le plus à cœur ?', 65))
# (('Sexe', 3), ('Sexe', 2))
# (('Quelle est votre catégorie socio-professionnelle ?', 10), ('Quelle est votre catégorie socio-professionnelle ?', 10))
# (("Tranche d'âge", 6), ("Tranche d'âge", 6))
# (('de combien de personnes se compose votre foyer ?', 5), ('de combien de personnes se compose votre foyer ?', 9))
# (("S'il y a des enfants dans votre foyer, quel âge ont-ils ?", 10), ("S'il y a des enfants dans votre foyer, quel âge ont-ils ?", 13))
# (('Êtes-vous abonné à notre newsletter ?', 2), ('Êtes-vous abonné à notre newsletter ?', 2))
# (('Si non, confiez-moi votre adresse mail pour recevoir notre actualité (moins de 10 mails par an)', 1), ('Si non, confiez-moi votre adresse mail pour recevoir notre actualité (moins de 10 mails par an)', 1))

# %%
df.loc[1,"code postal"]
# Out:
# 80209

# %%
# Get lon and lat
# import requests

# def set_lon_lat(df, postal_list):
#     df['lat'] = ""
#     df['lon'] = ""
    
#     responses_dic = {i:requests.get(f'https://nominatim.openstreetmap.org/search?q={str(i)}&format=json') for i in postal_list}
#     for index, row in df.iterrows():
#         df.loc[index, 'lat'] = responses_dic[df.loc[index, 'code postal']].json()[0]['lat']
#         df.loc[index, 'lon'] = responses_dic[df.loc[index, 'code postal']].json()[0]['lon'] 
#     df.to_csv('data_with_coordinates.csv', index=False)
# set_lon_lat(df2, postal_list)
